# %% [markdown]
# # K-NN con Hiperparámetros

# %% [markdown]
# ### k-NN (Nearest Neighbour)

# %% [markdown]
# - Se miran los k-casos más cercanos.
#
# - Se calcula la distancia media por clase o se asigna a la clase con más elementos.
#
# - El valor de k se suele determinar heurísticamente $k=\sqrt{n} $ donde n es el número de ejemplos. (Es una opción con base teórica)

# %% [markdown]
# ## 1. Librerias y configuraciones previas

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np


# Almacenar en caché los resultados de funciones en el disco
# ==============================================================================
import joblib


# Matemáticas y estadísticas
# ==============================================================================
import math


# Preprocesado y modelado
# ==============================================================================

#Separar los datos entrenamiento y prueba
from sklearn.model_selection import train_test_split


#Escalar Variables
from sklearn.preprocessing import MinMaxScaler


#Evaluación del modelo
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve


#Creación de modelo
from sklearn.neighbors import KNeighborsClassifier


#configuracion de hiperparámetros
from sklearn.model_selection import GridSearchCV


# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns


# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
## Cargar datos con colab
## =============================================================================

from google.colab import drive
import sys

# Path en google
PATH = '/gdrive/MyDrive/01_Academia/02_Cursos/20251001_AprendizajeAutomatico_UdeA/'

UTILS_PATH = PATH + 'utils/'
DATASET_PATH = PATH + 'datasets/'
MODELOS_PATH = PATH + 'modelos/'


# Montar Google Drive
drive.mount('/gdrive')

# Agregar utils al sys.path
sys.path.append(UTILS_PATH)
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ## 2. Funciones

# %%
# Funciones externas
# ==============================================================================
from funciones import multiple_plot, plot_roc_curve

# %% [markdown]
# ## 3. Carga del dataset

# %%
#Se crea un dataframe d con los datos obtenidos de archivo de entrada
d = pd.read_csv(DATASET_PATH + '02_GermanCredit_Prep.csv')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   checking_account_status   1138 non-null   object
#  1   loan_duration_mo          1138 non-null   int64
#  2   credit_history            1138 non-null   object
#  3   purpose                   1138 non-null   object
#  4   loan_amount               1138 non-null   int64
#  5   savings_account_balance   1138 non-null   object
#  6   time_employed_yrs         1138 non-null   object
#  7   payment_pcnt_income       1138 non-null   int64
#  8   gender_status             1138 non-null   object
#  9   other_signators           1138 non-null   object
#  10  time_in_residence         1138 non-null   int64
#  11  property                  1138 non-null   object
#  12  age_yrs                   1138 non-null   int64
#  13  other_credit_outstanding  1138 non-null   object
#  14  home_ownership            1138 non-null   object
#  15  number_loans              1138 non-null   int64
#  16  job_category              1138 non-null   object
#  17  dependents                1138 non-null   int64
#  18  telephone                 1138 non-null   object
#  19  foreign_worker            1138 non-null   object
#  20  bad_credit                1138 non-null   int64
# dtypes: int64(8), object(13)
# memory usage: 186.8+ KB

# %% [markdown]
# ## 4. Visualización de datos

# %% [markdown]
# ### Variables de entrada

# %%
#Lista de variables categóricas
catCols = d.select_dtypes(include = ["object", 'category']).columns.tolist()

d[catCols].head(2)
# Out:
#   checking_account_status                           credit_history purpose  \
# 0                  < 0 DM  critical account - other non-bank loans     car
# 1                  < 0 DM                       current loans paid     car
#
#   savings_account_balance time_employed_yrs  \
# 0                < 100 DM       1 - 4 years
# 1                < 100 DM       1 - 4 years
#
#                        gender_status other_signators     property  \
# 0  female-divorced/separated/married    co-applicant  real estate
# 1               male-married/widowed            none  real estate
#
#   other_credit_outstanding home_ownership        job_category telephone  \
# 0                     none            own             skilled      none
# 1                     none            own  unskilled-resident      none
#
#   foreign_worker
# 0            yes
# 1            yes

# %%
#Lista de variables numéricas

numCols=d.select_dtypes(include = ['float64','float64','int32','int64']).columns.tolist()

d[numCols].head(2)
# Out:
#    loan_duration_mo  loan_amount  payment_pcnt_income  time_in_residence  \
# 0                12         3499                    3                  2
# 1                12         1168                    4                  3
#
#    age_yrs  number_loans  dependents  bad_credit
# 0       29             2           1           1
# 1       27             1           1           0

# %%
##Visualización de frecuencia de instancias para variables categóricas
#multiple_plot(3, d , catCols, None, 'countplot', 'Frecuencia de instancias para variables categóricas',30)

# %%
##Visualización de variables numéricas
#multiple_plot(1, d , numCols, None, 'scatterplot', 'Relación entre las variables numéricas',30)

# %%
#Eliminar la variable de salida de la lista de variable numéricas
numCols.remove('bad_credit')

# %% [markdown]
# ### Variable de salida

# %%
# Distriución de la variable de salida

d.groupby('bad_credit').bad_credit.count().sort_values(ascending=False)
# Out:
# bad_credit
# 0    569
# 1    569
# Name: bad_credit, dtype: int64

# %%
##Visualización de la variable de salida
#multiple_plot(1, d , None, 'bad_credit', 'countplot', 'Gráfica de frecuencia de bad Credit',0)

# %% [markdown]
# ## 5. Transformación de datos

# %% [markdown]
# ### Creación de variables Dummies

# %%
# Aplicación de la función de usuario Dummies: one-hot encoding

d =pd.get_dummies(d, drop_first=1)

d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 46 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   loan_duration_mo                                        1138 non-null   int64
#  1   loan_amount                                             1138 non-null   int64
#  2   payment_pcnt_income                                     1138 non-null   int64
#  3   time_in_residence                                       1138 non-null   int64
#  4   age_yrs                                                 1138 non-null   int64
#  5   number_loans                                            1138 non-null   int64
#  6   dependents                                              1138 non-null   int64
#  7   bad_credit                                              1138 non-null   int64
#  8   checking_account_status_< 0 DM                          1138 non-null   bool
#  9   checking_account_status_> 200 DM or salary assignment   1138 non-null   bool
#  10  checking_account_status_none                            1138 non-null   bool
#  11  credit_history_critical account - other non-bank loans  1138 non-null   bool
#  12  credit_history_current loans paid                       1138 non-null   bool
#  13  credit_history_no credit - paid                         1138 non-null   bool
#  14  credit_history_past payment delays                      1138 non-null   bool
#  15  purpose_car                                             1138 non-null   bool
#  16  purpose_education                                       1138 non-null   bool
#  17  purpose_furniture/equipment                             1138 non-null   bool
#  18  purpose_other                                           1138 non-null   bool
#  19  purpose_radio/television                                1138 non-null   bool
#  20  purpose_repairs                                         1138 non-null   bool
#  21  savings_account_balance_500 - 1000 DM                   1138 non-null   bool
#  22  savings_account_balance_< 100 DM                        1138 non-null   bool
#  23  savings_account_balance_>= 1000 DM                      1138 non-null   bool
#  24  savings_account_balance_unknown/none                    1138 non-null   bool
#  25  time_employed_yrs_4 - 7 years                           1138 non-null   bool
#  26  time_employed_yrs_< 1 year                              1138 non-null   bool
#  27  time_employed_yrs_>= 7 years                            1138 non-null   bool
#  28  time_employed_yrs_unemployed                            1138 non-null   bool
#  29  gender_status_male-divorced/separated                   1138 non-null   bool
#  30  gender_status_male-married/widowed                      1138 non-null   bool
#  31  gender_status_male-single                               1138 non-null   bool
#  32  other_signators_guarantor                               1138 non-null   bool
#  33  other_signators_none                                    1138 non-null   bool
#  34  property_car or other                                   1138 non-null   bool
#  35  property_real estate                                    1138 non-null   bool
#  36  property_unknown-none                                   1138 non-null   bool
#  37  other_credit_outstanding_none                           1138 non-null   bool
#  38  other_credit_outstanding_stores                         1138 non-null   bool
#  39  home_ownership_own                                      1138 non-null   bool
#  40  home_ownership_rent                                     1138 non-null   bool
#  41  job_category_skilled                                    1138 non-null   bool
#  42  job_category_unemployed-unskilled-non-resident          1138 non-null   bool
#  43  job_category_unskilled-resident                         1138 non-null   bool
#  44  telephone_yes                                           1138 non-null   bool
#  45  foreign_worker_yes                                      1138 non-null   bool
# dtypes: bool(38), int64(8)
# memory usage: 113.5 KB

# %% [markdown]
# ## 6. Creación del modelo

# %% [markdown]
# ### Selecionar el conjunto de datos

# %%
#Se establece las variables de entrada 'X' y la variable de salida 'y'

X = d.drop(columns ='bad_credit')
y = d['bad_credit']

# la validación cruzada se realiza sobre todo el dataset
X_Completo = X
y_Completo = y

# %% [markdown]
# ### Escalar Variables

# %%
#Se establecen las variables numéricas a escalar

#Num_vars se le asigna la lista con las variables numerivas para posteriormente escalarlas
num_vars = numCols

print(num_vars)
# Out:
# ['loan_duration_mo', 'loan_amount', 'payment_pcnt_income', 'time_in_residence', 'age_yrs', 'number_loans', 'dependents']

# %%
#Escalar Variables númericas

pd.set_option('display.float_format', lambda x: '%.4f' % x)

# Se crea un objeto MinMaxScaler
scaler = MinMaxScaler()

# Se escalan los valores del dataset entrenamiento y prueba de las columnas numéricas
X_Completo[num_vars] = scaler.fit_transform(X_Completo[num_vars])


X_Completo[num_vars].head(2)
# Out:
#    loan_duration_mo  loan_amount  payment_pcnt_income  time_in_residence  \
# 0            0.1176       0.2356               0.6667             0.3333
# 1            0.1176       0.0619               1.0000             0.6667
#
#    age_yrs  number_loans  dependents
# 0   0.1667        0.3333      0.0000
# 1   0.1296        0.0000      0.0000

# %%
# Guardar el scaler
joblib.dump(scaler, MODELOS_PATH + '/scaler/minmaxFull_GermanCredits.pkl')
# Out:
# ['/gdrive/MyDrive/01_Academia/02_Cursos/20251001_AprendizajeAutomatico_UdeA/modelos//scaler/minmaxFull_GermanCredits.pkl']

# %% [markdown]
# ### Creación del modelo

# %% [markdown]
# #### Creación y entrenamiento del modelo

# %%
np.random.seed(4)


# Definición del modelo
modelKNN = KNeighborsClassifier()

#Número de vecinos a evaluar
k=[21, 25, 31, 35, 37]

# definicion de la variable con el número de pliegues
CV = 10

# valor de evaluación (scoring) del modelo
scoring = 'f1' # Otros valores que puede tomar son: accuracy, precision, recall2, f1, roc_auc, balanced_accuracy

# Definición de para
parameters = {'n_neighbors':k, 'metric':['euclidean','manhattan','chebyshev']}


# Creacion de gridSearch con los múltiples parámetros
grid_knn = GridSearchCV(estimator=modelKNN
                    , param_grid = parameters
                    , cv=CV
                    , scoring=scoring
                    , return_train_score=True
                    , verbose=4)


grid_knn.fit(X_Completo, y_Completo)
# Out:
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# [CV 1/10] END metric=euclidean, n_neighbors=21;, score=(train=0.717, test=0.698) total time=   0.1s
# [CV 2/10] END metric=euclidean, n_neighbors=21;, score=(train=0.729, test=0.703) total time=   0.0s
# [CV 3/10] END metric=euclidean, n_neighbors=21;, score=(train=0.720, test=0.726) total time=   0.0s
# [CV 4/10] END metric=euclidean, n_neighbors=21;, score=(train=0.726, test=0.730) total time=   0.0s
# [CV 5/10] END metric=euclidean, n_neighbors=21;, score=(train=0.718, test=0.708) total time=   0.0s
# [CV 6/10] END metric=euclidean, n_neighbors=21;, score=(train=0.726, test=0.631) total time=   0.0s
# [CV 7/10] END metric=euclidean, n_neighbors=21;, score=(train=0.726, test=0.694) total time=   0.0s
# [CV 8/10] END metric=euclidean, n_neighbors=21;, score=(train=0.729, test=0.739) total time=   0.0s
# [CV 9/10] END metric=euclidean, n_neighbors=21;, score=(train=0.722, test=0.655) total time=   0.0s
# [CV 10/10] END metric=euclidean, n_neighbors=21;, score=(train=0.728, test=0.678) total time=   0.0s
# [CV 1/10] END metric=euclidean, n_neighbors=25;, score=(train=0.739, test=0.714) total time=   0.0s
# [CV 2/10] END metric=euclidean, n_neighbors=25;, score=(train=0.733, test=0.708) total time=   0.0s
# [CV 3/10] END metric=euclidean, n_neighbors=25;, score=(train=0.713, test=0.726) total time=   0.0s
# [CV 4/10] END metric=euclidean, n_neighbors=25;, score=(train=0.721, test=0.696) total time=   0.0s
# [CV 5/10] END metric=euclidean, n_neighbors=25;, score=(train=0.729, test=0.718) total time=   0.0s
# [CV 6/10] END metric=euclidean, n_neighbors=25;, score=(train=0.722, test=0.625) total time=   0.0s
# [CV 7/10] END metric=euclidean, n_neighbors=25;, score=(train=0.721, test=0.650) total time=   0.0s
# [CV 8/10] END metric=euclidean, n_neighbors=25;, score=(train=0.740, test=0.758) total time=   0.0s
# [CV 9/10] END metric=euclidean, n_neighbors=25;, score=(train=0.732, test=0.679) total time=   0.0s
# [CV 10/10] END metric=euclidean, n_neighbors=25;, score=(train=0.727, test=0.661) total time=   0.0s
# [CV 1/10] END metric=euclidean, n_neighbors=31;, score=(train=0.707, test=0.703) total time=   0.0s
# [CV 2/10] END metric=euclidean, n_neighbors=31;, score=(train=0.716, test=0.743) total time=   0.0s
# [CV 3/10] END metric=euclidean, n_neighbors=31;, score=(train=0.706, test=0.726) total time=   0.0s
# [CV 4/10] END metric=euclidean, n_neighbors=31;, score=(train=0.708, test=0.661) total time=   0.0s
# [CV 5/10] END metric=euclidean, n_neighbors=31;, score=(train=0.728, test=0.712) total time=   0.0s
# [CV 6/10] END metric=euclidean, n_neighbors=31;, score=(train=0.712, test=0.636) total time=   0.0s
# [CV 7/10] END metric=euclidean, n_neighbors=31;, score=(train=0.703, test=0.667) total time=   0.0s
# [CV 8/10] END metric=euclidean, n_neighbors=31;, score=(train=0.716, test=0.739) total time=   0.0s
# [CV 9/10] END metric=euclidean, n_neighbors=31;, score=(train=0.718, test=0.696) total time=   0.0s
# [CV 10/10] END metric=euclidean, n_neighbors=31;, score=(train=0.733, test=0.667) total time=   0.0s
# [CV 1/10] END metric=euclidean, n_neighbors=35;, score=(train=0.720, test=0.713) total time=   0.0s
# [CV 2/10] END metric=euclidean, n_neighbors=35;, score=(train=0.723, test=0.732) total time=   0.0s
# [CV 3/10] END metric=euclidean, n_neighbors=35;, score=(train=0.730, test=0.713) total time=   0.0s
# [CV 4/10] END metric=euclidean, n_neighbors=35;, score=(train=0.708, test=0.661) total time=   0.0s
# [CV 5/10] END metric=euclidean, n_neighbors=35;, score=(train=0.725, test=0.701) total time=   0.0s
# [CV 6/10] END metric=euclidean, n_neighbors=35;, score=(train=0.720, test=0.643) total time=   0.0s
# [CV 7/10] END metric=euclidean, n_neighbors=35;, score=(train=0.713, test=0.695) total time=   0.0s
# [CV 8/10] END metric=euclidean, n_neighbors=35;, score=(train=0.711, test=0.711) total time=   0.0s
# [CV 9/10] END metric=euclidean, n_neighbors=35;, score=(train=0.723, test=0.719) total time=   0.0s
# [CV 10/10] END metric=euclidean, n_neighbors=35;, score=(train=0.719, test=0.667) total time=   0.0s
# [CV 1/10] END metric=euclidean, n_neighbors=37;, score=(train=0.715, test=0.693) total time=   0.0s
# [CV 2/10] END metric=euclidean, n_neighbors=37;, score=(train=0.715, test=0.727) total time=   0.0s
# [CV 3/10] END metric=euclidean, n_neighbors=37;, score=(train=0.733, test=0.735) total time=   0.0s
# [CV 4/10] END metric=euclidean, n_neighbors=37;, score=(train=0.720, test=0.673) total time=   0.0s
# [CV 5/10] END metric=euclidean, n_neighbors=37;, score=(train=0.715, test=0.695) total time=   0.0s
# [CV 6/10] END metric=euclidean, n_neighbors=37;, score=(train=0.720, test=0.643) total time=   0.0s
# [CV 7/10] END metric=euclidean, n_neighbors=37;, score=(train=0.716, test=0.712) total time=   0.0s
# [CV 8/10] END metric=euclidean, n_neighbors=37;, score=(train=0.715, test=0.723) total time=   0.0s
# [CV 9/10] END metric=euclidean, n_neighbors=37;, score=(train=0.716, test=0.708) total time=   0.0s
# [CV 10/10] END metric=euclidean, n_neighbors=37;, score=(train=0.711, test=0.661) total time=   0.0s
# [CV 1/10] END metric=manhattan, n_neighbors=21;, score=(train=0.718, test=0.688) total time=   0.0s
# [CV 2/10] END metric=manhattan, n_neighbors=21;, score=(train=0.732, test=0.703) total time=   0.0s
# [CV 3/10] END metric=manhattan, n_neighbors=21;, score=(train=0.720, test=0.714) total time=   0.0s
# [CV 4/10] END metric=manhattan, n_neighbors=21;, score=(train=0.718, test=0.713) total time=   0.0s
# [CV 5/10] END metric=manhattan, n_neighbors=21;, score=(train=0.731, test=0.752) total time=   0.0s
# [CV 6/10] END metric=manhattan, n_neighbors=21;, score=(train=0.724, test=0.661) total time=   0.0s
# [CV 7/10] END metric=manhattan, n_neighbors=21;, score=(train=0.729, test=0.689) total time=   0.0s
# [CV 8/10] END metric=manhattan, n_neighbors=21;, score=(train=0.742, test=0.723) total time=   0.0s
# [CV 9/10] END metric=manhattan, n_neighbors=21;, score=(train=0.720, test=0.631) total time=   0.0s
# [CV 10/10] END metric=manhattan, n_neighbors=21;, score=(train=0.738, test=0.718) total time=   0.0s
# [CV 1/10] END metric=manhattan, n_neighbors=25;, score=(train=0.742, test=0.682) total time=   0.0s
# [CV 2/10] END metric=manhattan, n_neighbors=25;, score=(train=0.730, test=0.704) total time=   0.0s
# [CV 3/10] END metric=manhattan, n_neighbors=25;, score=(train=0.719, test=0.727) total time=   0.0s
# [CV 4/10] END metric=manhattan, n_neighbors=25;, score=(train=0.729, test=0.684) total time=   0.0s
# [CV 5/10] END metric=manhattan, n_neighbors=25;, score=(train=0.742, test=0.718) total time=   0.0s
# [CV 6/10] END metric=manhattan, n_neighbors=25;, score=(train=0.722, test=0.636) total time=   0.0s
# [CV 7/10] END metric=manhattan, n_neighbors=25;, score=(train=0.724, test=0.690) total time=   0.0s
# [CV 8/10] END metric=manhattan, n_neighbors=25;, score=(train=0.730, test=0.719) total time=   0.0s
# [CV 9/10] END metric=manhattan, n_neighbors=25;, score=(train=0.730, test=0.655) total time=   0.0s
# [CV 10/10] END metric=manhattan, n_neighbors=25;, score=(train=0.711, test=0.655) total time=   0.0s
# [CV 1/10] END metric=manhattan, n_neighbors=31;, score=(train=0.728, test=0.702) total time=   0.0s
# [CV 2/10] END metric=manhattan, n_neighbors=31;, score=(train=0.712, test=0.768) total time=   0.0s
# [CV 3/10] END metric=manhattan, n_neighbors=31;, score=(train=0.721, test=0.726) total time=   0.0s
# [CV 4/10] END metric=manhattan, n_neighbors=31;, score=(train=0.712, test=0.661) total time=   0.0s
# [CV 5/10] END metric=manhattan, n_neighbors=31;, score=(train=0.729, test=0.719) total time=   0.0s
# [CV 6/10] END metric=manhattan, n_neighbors=31;, score=(train=0.708, test=0.642) total time=   0.0s
# [CV 7/10] END metric=manhattan, n_neighbors=31;, score=(train=0.717, test=0.724) total time=   0.0s
# [CV 8/10] END metric=manhattan, n_neighbors=31;, score=(train=0.720, test=0.746) total time=   0.0s
# [CV 9/10] END metric=manhattan, n_neighbors=31;, score=(train=0.714, test=0.696) total time=   0.0s
# [CV 10/10] END metric=manhattan, n_neighbors=31;, score=(train=0.718, test=0.689) total time=   0.0s
# [CV 1/10] END metric=manhattan, n_neighbors=35;, score=(train=0.728, test=0.687) total time=   0.0s
# [CV 2/10] END metric=manhattan, n_neighbors=35;, score=(train=0.715, test=0.775) total time=   0.0s
# [CV 3/10] END metric=manhattan, n_neighbors=35;, score=(train=0.718, test=0.667) total time=   0.0s
# [CV 4/10] END metric=manhattan, n_neighbors=35;, score=(train=0.724, test=0.637) total time=   0.0s
# [CV 5/10] END metric=manhattan, n_neighbors=35;, score=(train=0.715, test=0.696) total time=   0.0s
# [CV 6/10] END metric=manhattan, n_neighbors=35;, score=(train=0.711, test=0.631) total time=   0.0s
# [CV 7/10] END metric=manhattan, n_neighbors=35;, score=(train=0.718, test=0.706) total time=   0.0s
# [CV 8/10] END metric=manhattan, n_neighbors=35;, score=(train=0.710, test=0.701) total time=   0.0s
# [CV 9/10] END metric=manhattan, n_neighbors=35;, score=(train=0.720, test=0.726) total time=   0.0s
# [CV 10/10] END metric=manhattan, n_neighbors=35;, score=(train=0.710, test=0.661) total time=   0.0s
# [CV 1/10] END metric=manhattan, n_neighbors=37;, score=(train=0.717, test=0.688) total time=   0.0s
# [CV 2/10] END metric=manhattan, n_neighbors=37;, score=(train=0.703, test=0.757) total time=   0.0s
# [CV 3/10] END metric=manhattan, n_neighbors=37;, score=(train=0.716, test=0.696) total time=   0.0s
# [CV 4/10] END metric=manhattan, n_neighbors=37;, score=(train=0.716, test=0.649) total time=   0.0s
# [CV 5/10] END metric=manhattan, n_neighbors=37;, score=(train=0.711, test=0.673) total time=   0.0s
# [CV 6/10] END metric=manhattan, n_neighbors=37;, score=(train=0.717, test=0.636) total time=   0.0s
# [CV 7/10] END metric=manhattan, n_neighbors=37;, score=(train=0.717, test=0.729) total time=   0.0s
# [CV 8/10] END metric=manhattan, n_neighbors=37;, score=(train=0.713, test=0.690) total time=   0.0s
# [CV 9/10] END metric=manhattan, n_neighbors=37;, score=(train=0.715, test=0.748) total time=   0.0s
# [CV 10/10] END metric=manhattan, n_neighbors=37;, score=(train=0.706, test=0.655) total time=   0.0s
# [CV 1/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 2/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 3/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 4/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 5/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 6/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 7/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 8/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 9/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 10/10] END metric=chebyshev, n_neighbors=21;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 1/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 2/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 3/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 4/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 5/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 6/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 7/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 8/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 9/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 10/10] END metric=chebyshev, n_neighbors=25;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 1/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 2/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 3/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 4/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 5/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 6/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 7/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 8/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 9/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 10/10] END metric=chebyshev, n_neighbors=31;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 1/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 2/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 3/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 4/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 5/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 6/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 7/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 8/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 9/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 10/10] END metric=chebyshev, n_neighbors=35;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 1/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 2/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 3/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 4/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 5/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 6/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 7/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 8/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 9/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# [CV 10/10] END metric=chebyshev, n_neighbors=37;, score=(train=0.000, test=0.000) total time=   0.0s
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'chebyshev'],
#                          'n_neighbors': [21, 25, 31, 35, 37]},
#              return_train_score=True, scoring='f1', verbose=4)

# %% [markdown]
# ### Evaluación del modelo

# %%
#grid_knn.cv_results_

# %%
# Resultados
resultados = pd.DataFrame(grid_knn.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
# Out:
#   param_metric  param_n_neighbors  mean_test_score  std_test_score  \
# 7    manhattan                 31           0.7073          0.0358
# 5    manhattan                 21           0.6991          0.0325
# 4    euclidean                 37           0.6969          0.0287
# 0    euclidean                 21           0.6962          0.0323
#
#    mean_train_score  std_train_score
# 7            0.7180           0.0065
# 5            0.7274           0.0083
# 4            0.7174           0.0057
# 0            0.7240           0.0042

# %%
#grid_knn.cv_results_
#grid_knn.best_score_

# %%
# Obtener los resultados de la búsqueda de la cuadrícula para grid_knn
results_grid_knn = pd.DataFrame(grid_knn.cv_results_)

# Seleccionar las columnas deseadas
columns_grid_knn = ['param_metric', 'param_n_neighbors']  + \
               ['mean_test_score', 'std_test_score']  + \
               [f'split{i}_test_score' for i in range(CV)]

# Filtrar y mostrar los resultados
results_grid_knn_filtered = results_grid_knn[columns_grid_knn]

results_grid_knn_filtered.sort_values(by='mean_test_score', ascending=False).head(10)
# Out:
#   param_metric  param_n_neighbors  mean_test_score  std_test_score  \
# 7    manhattan                 31           0.7073          0.0358
# 5    manhattan                 21           0.6991          0.0325
# 4    euclidean                 37           0.6969          0.0287
# 0    euclidean                 21           0.6962          0.0323
# 3    euclidean                 35           0.6954          0.0276
# 2    euclidean                 31           0.6949          0.0344
# 1    euclidean                 25           0.6935          0.0378
# 9    manhattan                 37           0.6920          0.0393
# 8    manhattan                 35           0.6885          0.0407
# 6    manhattan                 25           0.6870          0.0293
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 7             0.7023             0.7679             0.7257             0.6607
# 5             0.6875             0.7027             0.7143             0.7130
# 4             0.6929             0.7273             0.7350             0.6726
# 0             0.6984             0.7027             0.7257             0.7304
# 3             0.7132             0.7321             0.7130             0.6607
# 2             0.7031             0.7434             0.7257             0.6606
# 1             0.7143             0.7080             0.7257             0.6957
# 9             0.6875             0.7568             0.6964             0.6486
# 8             0.6870             0.7748             0.6667             0.6372
# 6             0.6822             0.7037             0.7273             0.6842
#
#    split4_test_score  split5_test_score  split6_test_score  split7_test_score  \
# 7             0.7193             0.6422             0.7241             0.7458
# 5             0.7521             0.6609             0.6891             0.7227
# 4             0.6949             0.6429             0.7119             0.7227
# 0             0.7080             0.6306             0.6942             0.7395
# 3             0.7009             0.6429             0.6949             0.7107
# 2             0.7119             0.6364             0.6667             0.7395
# 1             0.7179             0.6250             0.6504             0.7581
# 9             0.6726             0.6364             0.7288             0.6897
# 8             0.6957             0.6306             0.7059             0.7009
# 6             0.7179             0.6364             0.6897             0.7193
#
#    split8_test_score  split9_test_score
# 7             0.6964             0.6891
# 5             0.6306             0.7179
# 4             0.7080             0.6610
# 0             0.6549             0.6780
# 3             0.7193             0.6667
# 2             0.6957             0.6667
# 1             0.6786             0.6610
# 9             0.7478             0.6552
# 8             0.7257             0.6609
# 6             0.6549             0.6549

# %%
# Resultados de grid_knn
print("Resultados grid_knn:")
print("Mejor score de validación (", scoring, "):"  ,grid_knn.best_score_)
print("Mejor conjunto de hiperparámetros:", grid_knn.best_params_)
# Out:
# Resultados grid_knn:
# Mejor score de validación ( f1 ): 0.7073430146777449
# Mejor conjunto de hiperparámetros: {'metric': 'manhattan', 'n_neighbors': 31}

# %% [markdown]
# ### Creación el modelo final

# %%
# Usar los mejores parámetros para ajustar el modelo
modelKNN.set_params(**grid_knn.best_params_)
modelKNN.fit(X_Completo, y_Completo)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=31)

# %% [markdown]
# ### Guardar modelo

# %%
#Se guarda el modelo de Regresión logística
joblib.dump(modelKNN, MODELOS_PATH + '/clasificacion/KNN_CV_manhattan.pkl')
# Out:
# ['/gdrive/MyDrive/01_Academia/02_Cursos/20251001_AprendizajeAutomatico_UdeA/modelos//clasificacion/KNN_CV_manhattan.pkl']

# %% [markdown]
# #### Referencias
#
#
# - K-Neighbors Classifier
#
#     - https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
#
#
# - Parámetros Regresion Logística
#
#     - https://holypython.com/log-reg/logistic-regression-optimization-parameters/
#
#
# - *scikit-learn:*
#     - https://scikit-learn.org/stable/modules/svm.html
#
#
#
# - *Gráficas con  seaborn:*
#     - https://ichi.pro/es/como-utilizar-python-seaborn-para-analisis-de-datos-exploratorios-28897898172180
#
#
#
# - *Analítica de grandes datos:*
#     - https://jdvelasq.github.io/courses/analitica-de-grandes-datos/index.html
