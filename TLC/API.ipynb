# %%
import pandas as pd
import requests
from io import BytesIO
import os

BASE_URL = "https://d37ci6vzurychx.cloudfront.net/trip-data"
OUTPUT_DIR = "tlc_data_s3"
os.makedirs(OUTPUT_DIR, exist_ok=True)

TYPES = ["yellow", "green", "fhvhv"]
YEARS = range(2022, 2026)

def download_parquet_file(taxi_type, year, month):
    file_name = f"{taxi_type}_tripdata_{year}-{month:02d}.parquet"
    url = f"{BASE_URL}/{file_name}"
    dest_path = os.path.join(OUTPUT_DIR, file_name)

    if os.path.exists(dest_path):
        print(f"⚠️ Ya existe: {file_name}")
        return

    try:
        print(f"⬇️ Descargando {file_name}...")
        resp = requests.get(url, timeout=30)
        if resp.status_code == 200:
            df = pd.read_parquet(BytesIO(resp.content))
            df.to_parquet(dest_path, index=False, compression="snappy")
            print(f"✅ Guardado {file_name} ({len(df):,} filas)")
        else:
            print(f"❌ No encontrado ({resp.status_code}): {url}")
    except Exception as e:
        print(f"⚠️ Error con {file_name}: {e}")

for taxi_type in TYPES:
    for year in YEARS:
        for month in range(1, 13):
            download_parquet_file(taxi_type, year, month)
# Out:
# ⬇️ Descargando yellow_tripdata_2022-01.parquet...
# ✅ Guardado yellow_tripdata_2022-01.parquet (2,463,931 filas)
# ⬇️ Descargando yellow_tripdata_2022-02.parquet...
# ✅ Guardado yellow_tripdata_2022-02.parquet (2,979,431 filas)
# ⬇️ Descargando yellow_tripdata_2022-03.parquet...
# ✅ Guardado yellow_tripdata_2022-03.parquet (3,627,882 filas)
# ⬇️ Descargando yellow_tripdata_2022-04.parquet...
# ✅ Guardado yellow_tripdata_2022-04.parquet (3,599,920 filas)
# ⬇️ Descargando yellow_tripdata_2022-05.parquet...
# ✅ Guardado yellow_tripdata_2022-05.parquet (3,588,295 filas)
# ⬇️ Descargando yellow_tripdata_2022-06.parquet...
# ✅ Guardado yellow_tripdata_2022-06.parquet (3,558,124 filas)
# ⬇️ Descargando yellow_tripdata_2022-07.parquet...
# ✅ Guardado yellow_tripdata_2022-07.parquet (3,174,394 filas)
# ⬇️ Descargando yellow_tripdata_2022-08.parquet...
# ✅ Guardado yellow_tripdata_2022-08.parquet (3,152,677 filas)
# ⬇️ Descargando yellow_tripdata_2022-09.parquet...
# ✅ Guardado yellow_tripdata_2022-09.parquet (3,183,767 filas)
# ⬇️ Descargando yellow_tripdata_2022-10.parquet...
# ✅ Guardado yellow_tripdata_2022-10.parquet (3,675,411 filas)
# ⬇️ Descargando yellow_tripdata_2022-11.parquet...
# ✅ Guardado yellow_tripdata_2022-11.parquet (3,252,717 filas)
# ⬇️ Descargando yellow_tripdata_2022-12.parquet...
# ✅ Guardado yellow_tripdata_2022-12.parquet (3,399,549 filas)
# ⬇️ Descargando yellow_tripdata_2023-01.parquet...
# ✅ Guardado yellow_tripdata_2023-01.parquet (3,066,766 filas)
# ⬇️ Descargando yellow_tripdata_2023-02.parquet...
# ✅ Guardado yellow_tripdata_2023-02.parquet (2,913,955 filas)
# ⬇️ Descargando yellow_tripdata_2023-03.parquet...
# ✅ Guardado yellow_tripdata_2023-03.parquet (3,403,766 filas)
# ⬇️ Descargando yellow_tripdata_2023-04.parquet...
# ✅ Guardado yellow_tripdata_2023-04.parquet (3,288,250 filas)
# ⬇️ Descargando yellow_tripdata_2023-05.parquet...
# ✅ Guardado yellow_tripdata_2023-05.parquet (3,513,649 filas)
# ⬇️ Descargando yellow_tripdata_2023-06.parquet...
# ✅ Guardado yellow_tripdata_2023-06.parquet (3,307,234 filas)
# ⬇️ Descargando yellow_tripdata_2023-07.parquet...
# ✅ Guardado yellow_tripdata_2023-07.parquet (2,907,108 filas)
# ⬇️ Descargando yellow_tripdata_2023-08.parquet...
# ✅ Guardado yellow_tripdata_2023-08.parquet (2,824,209 filas)
# ⬇️ Descargando yellow_tripdata_2023-09.parquet...
# ✅ Guardado yellow_tripdata_2023-09.parquet (2,846,722 filas)
# ⬇️ Descargando yellow_tripdata_2023-10.parquet...
# ✅ Guardado yellow_tripdata_2023-10.parquet (3,522,285 filas)
# ⬇️ Descargando yellow_tripdata_2023-11.parquet...
# ✅ Guardado yellow_tripdata_2023-11.parquet (3,339,715 filas)
# ⬇️ Descargando yellow_tripdata_2023-12.parquet...
# ✅ Guardado yellow_tripdata_2023-12.parquet (3,376,567 filas)
# ⬇️ Descargando yellow_tripdata_2024-01.parquet...
# ✅ Guardado yellow_tripdata_2024-01.parquet (2,964,624 filas)
# ⬇️ Descargando yellow_tripdata_2024-02.parquet...
# ✅ Guardado yellow_tripdata_2024-02.parquet (3,007,526 filas)
# ⬇️ Descargando yellow_tripdata_2024-03.parquet...
# ✅ Guardado yellow_tripdata_2024-03.parquet (3,582,628 filas)
# ⬇️ Descargando yellow_tripdata_2024-04.parquet...
# ✅ Guardado yellow_tripdata_2024-04.parquet (3,514,289 filas)
# ⬇️ Descargando yellow_tripdata_2024-05.parquet...
# ✅ Guardado yellow_tripdata_2024-05.parquet (3,723,833 filas)
# ⬇️ Descargando yellow_tripdata_2024-06.parquet...
# ✅ Guardado yellow_tripdata_2024-06.parquet (3,539,193 filas)
# ⬇️ Descargando yellow_tripdata_2024-07.parquet...
# ✅ Guardado yellow_tripdata_2024-07.parquet (3,076,903 filas)
# ⬇️ Descargando yellow_tripdata_2024-08.parquet...
# ✅ Guardado yellow_tripdata_2024-08.parquet (2,979,183 filas)
# ⬇️ Descargando yellow_tripdata_2024-09.parquet...
# ✅ Guardado yellow_tripdata_2024-09.parquet (3,633,030 filas)
# ⬇️ Descargando yellow_tripdata_2024-10.parquet...
# ✅ Guardado yellow_tripdata_2024-10.parquet (3,833,771 filas)
# ⬇️ Descargando yellow_tripdata_2024-11.parquet...
# ✅ Guardado yellow_tripdata_2024-11.parquet (3,646,369 filas)
# ⬇️ Descargando yellow_tripdata_2024-12.parquet...
# ✅ Guardado yellow_tripdata_2024-12.parquet (3,668,371 filas)
# ⬇️ Descargando yellow_tripdata_2025-01.parquet...
# ✅ Guardado yellow_tripdata_2025-01.parquet (3,475,226 filas)
# ⬇️ Descargando yellow_tripdata_2025-02.parquet...
# ✅ Guardado yellow_tripdata_2025-02.parquet (3,577,543 filas)
# ⬇️ Descargando yellow_tripdata_2025-03.parquet...
# ✅ Guardado yellow_tripdata_2025-03.parquet (4,145,257 filas)
# ⬇️ Descargando yellow_tripdata_2025-04.parquet...
# ✅ Guardado yellow_tripdata_2025-04.parquet (3,970,553 filas)
# ⬇️ Descargando yellow_tripdata_2025-05.parquet...
# ✅ Guardado yellow_tripdata_2025-05.parquet (4,591,845 filas)
# ⬇️ Descargando yellow_tripdata_2025-06.parquet...
# ✅ Guardado yellow_tripdata_2025-06.parquet (4,322,960 filas)
# ⬇️ Descargando yellow_tripdata_2025-07.parquet...
# ✅ Guardado yellow_tripdata_2025-07.parquet (3,898,963 filas)
# ⬇️ Descargando yellow_tripdata_2025-08.parquet...
# ✅ Guardado yellow_tripdata_2025-08.parquet (3,574,091 filas)
# ⬇️ Descargando yellow_tripdata_2025-09.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-09.parquet
# ⬇️ Descargando yellow_tripdata_2025-10.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-10.parquet
# ⬇️ Descargando yellow_tripdata_2025-11.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet
# ⬇️ Descargando yellow_tripdata_2025-12.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-12.parquet
# ⬇️ Descargando green_tripdata_2022-01.parquet...
# ✅ Guardado green_tripdata_2022-01.parquet (62,495 filas)
# ⬇️ Descargando green_tripdata_2022-02.parquet...
# ✅ Guardado green_tripdata_2022-02.parquet (69,399 filas)
# ⬇️ Descargando green_tripdata_2022-03.parquet...
# ✅ Guardado green_tripdata_2022-03.parquet (78,537 filas)
# ⬇️ Descargando green_tripdata_2022-04.parquet...
# ✅ Guardado green_tripdata_2022-04.parquet (76,136 filas)
# ⬇️ Descargando green_tripdata_2022-05.parquet...
# ✅ Guardado green_tripdata_2022-05.parquet (76,891 filas)
# ⬇️ Descargando green_tripdata_2022-06.parquet...
# ✅ Guardado green_tripdata_2022-06.parquet (73,718 filas)
# ⬇️ Descargando green_tripdata_2022-07.parquet...
# ✅ Guardado green_tripdata_2022-07.parquet (64,192 filas)
# ⬇️ Descargando green_tripdata_2022-08.parquet...
# ✅ Guardado green_tripdata_2022-08.parquet (65,929 filas)
# ⬇️ Descargando green_tripdata_2022-09.parquet...
# ✅ Guardado green_tripdata_2022-09.parquet (69,031 filas)
# ⬇️ Descargando green_tripdata_2022-10.parquet...
# ✅ Guardado green_tripdata_2022-10.parquet (69,322 filas)
# ⬇️ Descargando green_tripdata_2022-11.parquet...
# ✅ Guardado green_tripdata_2022-11.parquet (62,313 filas)
# ⬇️ Descargando green_tripdata_2022-12.parquet...
# ✅ Guardado green_tripdata_2022-12.parquet (72,439 filas)
# ⬇️ Descargando green_tripdata_2023-01.parquet...
# ✅ Guardado green_tripdata_2023-01.parquet (68,211 filas)
# ⬇️ Descargando green_tripdata_2023-02.parquet...
# ✅ Guardado green_tripdata_2023-02.parquet (64,809 filas)
# ⬇️ Descargando green_tripdata_2023-03.parquet...
# ✅ Guardado green_tripdata_2023-03.parquet (72,044 filas)
# ⬇️ Descargando green_tripdata_2023-04.parquet...
# ✅ Guardado green_tripdata_2023-04.parquet (65,392 filas)
# ⬇️ Descargando green_tripdata_2023-05.parquet...
# ✅ Guardado green_tripdata_2023-05.parquet (69,174 filas)
# ⬇️ Descargando green_tripdata_2023-06.parquet...
# ✅ Guardado green_tripdata_2023-06.parquet (65,550 filas)
# ⬇️ Descargando green_tripdata_2023-07.parquet...
# ✅ Guardado green_tripdata_2023-07.parquet (61,343 filas)
# ⬇️ Descargando green_tripdata_2023-08.parquet...
# ✅ Guardado green_tripdata_2023-08.parquet (60,649 filas)
# ⬇️ Descargando green_tripdata_2023-09.parquet...
# ✅ Guardado green_tripdata_2023-09.parquet (65,471 filas)
# ⬇️ Descargando green_tripdata_2023-10.parquet...
# ✅ Guardado green_tripdata_2023-10.parquet (66,177 filas)
# ⬇️ Descargando green_tripdata_2023-11.parquet...
# ✅ Guardado green_tripdata_2023-11.parquet (64,025 filas)
# ⬇️ Descargando green_tripdata_2023-12.parquet...
# ✅ Guardado green_tripdata_2023-12.parquet (64,215 filas)
# ⬇️ Descargando green_tripdata_2024-01.parquet...
# ✅ Guardado green_tripdata_2024-01.parquet (56,551 filas)
# ⬇️ Descargando green_tripdata_2024-02.parquet...
# ✅ Guardado green_tripdata_2024-02.parquet (53,577 filas)
# ⬇️ Descargando green_tripdata_2024-03.parquet...
# ✅ Guardado green_tripdata_2024-03.parquet (57,457 filas)
# ⬇️ Descargando green_tripdata_2024-04.parquet...
# ✅ Guardado green_tripdata_2024-04.parquet (56,471 filas)
# ⬇️ Descargando green_tripdata_2024-05.parquet...
# ✅ Guardado green_tripdata_2024-05.parquet (61,003 filas)
# ⬇️ Descargando green_tripdata_2024-06.parquet...
# ✅ Guardado green_tripdata_2024-06.parquet (54,748 filas)
# ⬇️ Descargando green_tripdata_2024-07.parquet...
# ✅ Guardado green_tripdata_2024-07.parquet (51,837 filas)
# ⬇️ Descargando green_tripdata_2024-08.parquet...
# ✅ Guardado green_tripdata_2024-08.parquet (51,771 filas)
# ⬇️ Descargando green_tripdata_2024-09.parquet...
# ✅ Guardado green_tripdata_2024-09.parquet (54,440 filas)
# ⬇️ Descargando green_tripdata_2024-10.parquet...
# ✅ Guardado green_tripdata_2024-10.parquet (56,147 filas)
# ⬇️ Descargando green_tripdata_2024-11.parquet...
# ✅ Guardado green_tripdata_2024-11.parquet (52,222 filas)
# ⬇️ Descargando green_tripdata_2024-12.parquet...
# ✅ Guardado green_tripdata_2024-12.parquet (53,994 filas)
# ⬇️ Descargando green_tripdata_2025-01.parquet...
# ✅ Guardado green_tripdata_2025-01.parquet (48,326 filas)
# ⬇️ Descargando green_tripdata_2025-02.parquet...
# ✅ Guardado green_tripdata_2025-02.parquet (46,621 filas)
# ⬇️ Descargando green_tripdata_2025-03.parquet...
# ✅ Guardado green_tripdata_2025-03.parquet (51,539 filas)
# ⬇️ Descargando green_tripdata_2025-04.parquet...
# ✅ Guardado green_tripdata_2025-04.parquet (52,132 filas)
# ⬇️ Descargando green_tripdata_2025-05.parquet...
# ✅ Guardado green_tripdata_2025-05.parquet (55,399 filas)
# ⬇️ Descargando green_tripdata_2025-06.parquet...
# ✅ Guardado green_tripdata_2025-06.parquet (49,390 filas)
# ⬇️ Descargando green_tripdata_2025-07.parquet...
# ✅ Guardado green_tripdata_2025-07.parquet (48,205 filas)
# ⬇️ Descargando green_tripdata_2025-08.parquet...
# ✅ Guardado green_tripdata_2025-08.parquet (46,306 filas)
# ⬇️ Descargando green_tripdata_2025-09.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-09.parquet
# ⬇️ Descargando green_tripdata_2025-10.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-10.parquet
# ⬇️ Descargando green_tripdata_2025-11.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# ⬇️ Descargando green_tripdata_2025-12.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-12.parquet
# ⬇️ Descargando fhvhv_tripdata_2022-01.parquet...
# ✅ Guardado fhvhv_tripdata_2022-01.parquet (14,751,591 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-02.parquet...
# ✅ Guardado fhvhv_tripdata_2022-02.parquet (16,019,283 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-03.parquet...
# ✅ Guardado fhvhv_tripdata_2022-03.parquet (18,453,548 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-04.parquet...
# ✅ Guardado fhvhv_tripdata_2022-04.parquet (17,752,561 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-05.parquet...
# ✅ Guardado fhvhv_tripdata_2022-05.parquet (18,157,335 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-06.parquet...
# ✅ Guardado fhvhv_tripdata_2022-06.parquet (17,780,075 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-07.parquet...
# ✅ Guardado fhvhv_tripdata_2022-07.parquet (17,464,619 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-08.parquet...
# ✅ Guardado fhvhv_tripdata_2022-08.parquet (17,185,687 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-09.parquet...
# ✅ Guardado fhvhv_tripdata_2022-09.parquet (17,793,551 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-10.parquet...
# ✅ Guardado fhvhv_tripdata_2022-10.parquet (19,306,090 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-11.parquet...
# ✅ Guardado fhvhv_tripdata_2022-11.parquet (18,085,896 filas)
# ⬇️ Descargando fhvhv_tripdata_2022-12.parquet...
# ✅ Guardado fhvhv_tripdata_2022-12.parquet (19,665,847 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-01.parquet...
# ✅ Guardado fhvhv_tripdata_2023-01.parquet (18,479,031 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-02.parquet...
# ✅ Guardado fhvhv_tripdata_2023-02.parquet (17,960,971 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-03.parquet...
# ✅ Guardado fhvhv_tripdata_2023-03.parquet (20,413,539 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-04.parquet...
# ✅ Guardado fhvhv_tripdata_2023-04.parquet (19,144,903 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-05.parquet...
# ✅ Guardado fhvhv_tripdata_2023-05.parquet (19,847,676 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-06.parquet...
# ✅ Guardado fhvhv_tripdata_2023-06.parquet (19,366,619 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-07.parquet...
# ✅ Guardado fhvhv_tripdata_2023-07.parquet (19,132,131 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-08.parquet...
# ✅ Guardado fhvhv_tripdata_2023-08.parquet (18,322,150 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-09.parquet...
# ✅ Guardado fhvhv_tripdata_2023-09.parquet (19,851,123 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-10.parquet...
# ✅ Guardado fhvhv_tripdata_2023-10.parquet (20,186,330 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-11.parquet...
# ✅ Guardado fhvhv_tripdata_2023-11.parquet (19,269,250 filas)
# ⬇️ Descargando fhvhv_tripdata_2023-12.parquet...
# ✅ Guardado fhvhv_tripdata_2023-12.parquet (20,516,297 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-01.parquet...
# ✅ Guardado fhvhv_tripdata_2024-01.parquet (19,663,930 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-02.parquet...
# ✅ Guardado fhvhv_tripdata_2024-02.parquet (19,359,148 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-03.parquet...
# ✅ Guardado fhvhv_tripdata_2024-03.parquet (21,280,788 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-04.parquet...
# ✅ Guardado fhvhv_tripdata_2024-04.parquet (19,733,038 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-05.parquet...
# ✅ Guardado fhvhv_tripdata_2024-05.parquet (20,704,538 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-06.parquet...
# ✅ Guardado fhvhv_tripdata_2024-06.parquet (20,123,226 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-07.parquet...
# ✅ Guardado fhvhv_tripdata_2024-07.parquet (19,182,934 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-08.parquet...
# ✅ Guardado fhvhv_tripdata_2024-08.parquet (19,128,392 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-09.parquet...
# ✅ Guardado fhvhv_tripdata_2024-09.parquet (19,209,788 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-10.parquet...
# ✅ Guardado fhvhv_tripdata_2024-10.parquet (20,028,282 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-11.parquet...
# ✅ Guardado fhvhv_tripdata_2024-11.parquet (19,987,533 filas)
# ⬇️ Descargando fhvhv_tripdata_2024-12.parquet...
# ✅ Guardado fhvhv_tripdata_2024-12.parquet (21,068,851 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-01.parquet...
# ✅ Guardado fhvhv_tripdata_2025-01.parquet (20,405,666 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-02.parquet...
# ✅ Guardado fhvhv_tripdata_2025-02.parquet (19,339,461 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-03.parquet...
# ✅ Guardado fhvhv_tripdata_2025-03.parquet (20,536,879 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-04.parquet...
# ✅ Guardado fhvhv_tripdata_2025-04.parquet (19,753,983 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-05.parquet...
# ✅ Guardado fhvhv_tripdata_2025-05.parquet (21,091,193 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-06.parquet...
# ✅ Guardado fhvhv_tripdata_2025-06.parquet (19,868,009 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-07.parquet...
# ✅ Guardado fhvhv_tripdata_2025-07.parquet (19,653,012 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-08.parquet...
# ✅ Guardado fhvhv_tripdata_2025-08.parquet (19,271,461 filas)
# ⬇️ Descargando fhvhv_tripdata_2025-09.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_2025-09.parquet
# ⬇️ Descargando fhvhv_tripdata_2025-10.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_2025-10.parquet
# ⬇️ Descargando fhvhv_tripdata_2025-11.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_2025-11.parquet
# ⬇️ Descargando fhvhv_tripdata_2025-12.parquet...
# ❌ No encontrado (403): https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_2025-12.parquet

# %%
def normalize_columns(df: pd.DataFrame, trip_type: str) -> pd.DataFrame:
    """
    Mapea campos a un esquema unificado:
    - pickup_datetime, dropoff_datetime
    - pickup_location_id, dropoff_location_id
    - trip_distance
    - fare_amount
    - trip_minutes (si se puede calcular)
    """

    df = df.copy()

    # Datetime: diferentes nombres según dataset
    time_map = [
        ("tpep_pickup_datetime", "pickup_datetime"),
        ("lpep_pickup_datetime", "pickup_datetime"),
        ("pickup_datetime", "pickup_datetime"),
        ("request_datetime", "pickup_datetime"),
        ("tpep_dropoff_datetime", "dropoff_datetime"),
        ("lpep_dropoff_datetime", "dropoff_datetime"),
        ("dropoff_datetime", "dropoff_datetime"),
    ]
    for src, dst in time_map:
        if src in df.columns:
            df.rename(columns={src: dst}, inplace=True)

    # ✅ eliminar columnas duplicadas tras renombrar
    df = df.loc[:, ~df.columns.duplicated()]

    # Location IDs
    loc_map = [
        ("pulocationid", "pickup_location_id"),
        ("dolocationid", "dropoff_location_id"),
        ("PULocationID", "pickup_location_id"),
        ("DOLocationID", "dropoff_location_id"),
    ]
    for src, dst in loc_map:
        if src in df.columns:
            df.rename(columns={src: dst}, inplace=True)

    df = df.loc[:, ~df.columns.duplicated()]  # otra limpieza

    # Distancia
    if "trip_distance" not in df.columns:
        if "trip_miles" in df.columns:
            df.rename(columns={"trip_miles": "trip_distance"}, inplace=True)

    # Tarifa
    if "fare_amount" not in df.columns:
        if "base_passenger_fare" in df.columns:
            df.rename(columns={"base_passenger_fare": "fare_amount"}, inplace=True)
        elif "total_amount" in df.columns:
            df.rename(columns={"total_amount": "fare_amount"}, inplace=True)

    # Casting datetime
    for col in ["pickup_datetime", "dropoff_datetime"]:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col], errors="coerce")

    # Trip minutes
    if "pickup_datetime" in df.columns and "dropoff_datetime" in df.columns:
        dt = (df["dropoff_datetime"] - df["pickup_datetime"]).dt.total_seconds() / 60.0
        df["trip_minutes"] = dt
    else:
        df["trip_minutes"] = np.nan

    # Asegurar columnas mínimas
    keep = [
        "pickup_datetime", "dropoff_datetime",
        "pickup_location_id", "dropoff_location_id",
        "trip_distance", "fare_amount", "trip_minutes"
    ]
    for col in keep:
        if col not in df.columns:
            df[col] = np.nan

    df["trip_type"] = trip_type
    df = df.loc[:, ~df.columns.duplicated()]  # limpieza final
    return df[keep + ["trip_type"]]

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# pip install pandas pyarrow numpy scipy tqdm

import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import re

# ===============================
# CONFIGURACIÓN
# ===============================
DATA_DIR = Path("tlc_data_s3")
REFERENCE = (2025, 1)
OUT_DIR = Path("analysis_outputs")
OUT_DIR.mkdir(exist_ok=True)

# ===============================
# FUNCIONES AUXILIARES
# ===============================
def detect_trip_type(name: str):
    name = name.lower()
    if "yellow" in name: return "yellow"
    if "green" in name: return "green"
    if "fhvhv" in name: return "fhvhv"
    return "unknown"

def parse_year_month(name: str):
    m = re.search(r"(\d{4})-(\d{2})", name)
    if not m:
        raise ValueError(f"No puedo extraer año/mes de {name}")
    return int(m.group(1)), int(m.group(2))

def jensen_shannon(p, q):
    p, q = np.asarray(p), np.asarray(q)
    p, q = p / p.sum(), q / q.sum()
    m = 0.5 * (p + q)
    mask = (p > 0) & (q > 0)
    kl = lambda a, b: np.sum(a[mask] * np.log2(a[mask]/b[mask]))
    return np.sqrt(0.5*kl(p, m) + 0.5*kl(q, m))

def summarize_file(path: Path):
    """Lee un solo archivo Parquet (independientemente del tipo) y calcula métricas clave."""
    # Intentamos leer solo columnas relevantes (las que existan realmente)
    desired_cols = [
        "tpep_pickup_datetime", "lpep_pickup_datetime", "request_datetime",
        "tpep_dropoff_datetime", "lpep_dropoff_datetime", "dropoff_datetime",
        "trip_distance", "fare_amount", "base_passenger_fare", "trip_miles",
    ]

    # Detectar columnas existentes sin cargar todo el dataset
    import pyarrow.parquet as pq
    schema = pq.read_schema(path)
    available = [c for c in desired_cols if c in schema.names]

    df = pd.read_parquet(path, columns=available)
    trip_type = detect_trip_type(path.name)
    year, month = parse_year_month(path.name)

    # Determinar columnas de tiempo (pickups y dropoffs)
    pickup_col = next(
        (c for c in ["tpep_pickup_datetime", "lpep_pickup_datetime", "request_datetime", "pickup_datetime"]
         if c in df.columns), None)
    drop_col = next(
        (c for c in ["tpep_dropoff_datetime", "lpep_dropoff_datetime", "dropoff_datetime"]
         if c in df.columns), None)

    if pickup_col is None:
        print(f"⚠️ No hay columna pickup en {path.name}, se omite.")
        return None

    df["pickup"] = pd.to_datetime(df[pickup_col], errors="coerce")
    df["hour"] = df["pickup"].dt.hour
    df["wday"] = df["pickup"].dt.dayofweek

    if drop_col in df.columns:
        df["drop"] = pd.to_datetime(df[drop_col], errors="coerce")
        df["minutes"] = (df["drop"] - df["pickup"]).dt.total_seconds() / 60.0
    else:
        df["minutes"] = np.nan

    # Unificar distancia y tarifa
    if "trip_distance" not in df.columns and "trip_miles" in df.columns:
        df["trip_distance"] = df["trip_miles"]
    if "fare_amount" not in df.columns and "base_passenger_fare" in df.columns:
        df["fare_amount"] = df["base_passenger_fare"]

    valid = (df["trip_distance"] > 0) & (df["fare_amount"] > 0)
    fare_per_mile = (df.loc[valid, "fare_amount"] / df.loc[valid, "trip_distance"]).mean()

    summary = {
        "year": year,
        "month": month,
        "trip_type": trip_type,
        "count": len(df),
        "avg_trip_distance": df["trip_distance"].mean(),
        "avg_minutes": df["minutes"].mean(),
        "avg_fare_per_mile": fare_per_mile,
        "hourly": np.bincount(df["hour"].dropna().astype(int), minlength=24),
        "wday": np.bincount(df["wday"].dropna().astype(int), minlength=7)
    }
    return summary


# ===============================
# PIPELINE PRINCIPAL
# ===============================
def main():
    print("🔄 Analizando por archivo (streaming)…")
    summaries = []

    files = sorted(DATA_DIR.glob("*.parquet"))
    for f in tqdm(files):
        s = summarize_file(f)
        if s:
            summaries.append(s)

    # Construir DataFrame compacto
    df_sum = pd.DataFrame(summaries)
    df_sum["hourly_norm"] = df_sum["hourly"].apply(lambda x: x/x.sum() if x.sum()>0 else np.ones(24)/24)
    df_sum["wday_norm"] = df_sum["wday"].apply(lambda x: x/x.sum() if x.sum()>0 else np.ones(7)/7)

    # Referencia enero 2025 combinando tipos
    ref_mask = (df_sum["year"]==REFERENCE[0]) & (df_sum["month"]==REFERENCE[1])
    ref = df_sum.loc[ref_mask]
    ref_hour = np.sum(np.stack(ref["hourly_norm"]), axis=0)
    ref_wday = np.sum(np.stack(ref["wday_norm"]), axis=0)
    ref_hour /= ref_hour.sum()
    ref_wday /= ref_wday.sum()

    # Comparar cada mes con referencia
    results = []
    for _, r in df_sum.iterrows():
        js_h = jensen_shannon(r["hourly_norm"], ref_hour)
        js_w = jensen_shannon(r["wday_norm"], ref_wday)
        results.append({
            "year": r["year"],
            "month": r["month"],
            "trip_type": r["trip_type"],
            "count": r["count"],
            "avg_trip_distance": r["avg_trip_distance"],
            "avg_minutes": r["avg_minutes"],
            "avg_fare_per_mile": r["avg_fare_per_mile"],
            "js_hour": js_h,
            "js_wday": js_w
        })
    df_out = pd.DataFrame(results)
    out_path = OUT_DIR / "monthly_patterns_vs_2025_01.csv"
    df_out.to_csv(out_path, index=False)
    print(f"✅ Guardado resumen en {out_path}")

    # Informe por año
    agg = (df_out.groupby(["year"])
           .agg(count_mean=("count","mean"),
                js_hour_mean=("js_hour","mean"),
                js_wday_mean=("js_wday","mean"))
           .reset_index())
    print("\nResumen anual:")
    print(agg)

if __name__ == "__main__":
    main()
# Out:
# 🔄 Analizando por archivo (streaming)…
# 100%|██████████| 132/132 [01:46<00:00,  1.24it/s]
# ✅ Guardado resumen en analysis_outputs\monthly_patterns_vs_2025_01.csv
#
# Resumen anual:
#    year    count_mean  js_hour_mean  js_wday_mean
# 0  2022  7.025350e+06      0.075898      0.071348
# 1  2023  7.544092e+06      0.072559      0.068045
# 2  2024  7.813900e+06      0.072837      0.072460
# 3  2025  7.994751e+06      0.074709      0.069334

# %%
import pandas as pd
import numpy as np
from pathlib import Path

IN_CSV  = Path("analysis_outputs/monthly_patterns_vs_2025_01.csv")
OUT_DIR = Path("analysis_outputs")
OUT_DIR.mkdir(exist_ok=True)

# =========================
# Cargar datos
# =========================
df = pd.read_csv(IN_CSV)

# Limpieza ligera
# Aseguramos tipos correctos y evitamos NaNs problemáticos en cálculos
num_cols = ["count", "avg_trip_distance", "avg_minutes", "avg_fare_per_mile", "js_hour", "js_wday"]
for c in num_cols:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")

# =========================
# 1) JS por tipo y año
# =========================
js_by_type_year = (df
    .groupby(["year", "trip_type"], as_index=False)
    .agg(js_hour_mean=("js_hour","mean"),
         js_wday_mean=("js_wday","mean"),
         count_mean=("count","mean"))
    .sort_values(["year","trip_type"])
)
js_by_type_year.to_csv(OUT_DIR/"js_by_type_year.csv", index=False)
print("✅ js_by_type_year.csv guardado")

# Versión agregada (todos los tipos combinados por año)
js_all_year = (df
    .groupby(["year"], as_index=False)
    .agg(js_hour_mean=("js_hour","mean"),
         js_wday_mean=("js_wday","mean"),
         count_mean=("count","mean"))
    .sort_values("year")
)
js_all_year.to_csv(OUT_DIR/"js_all_year.csv", index=False)
print("✅ js_all_year.csv guardado")

# =========================
# 2) Estacionalidad mensual
#    VISTA A: cada (año,mes) vs enero-2025 (todos los tipos)
# =========================
ref = df[(df["year"]==2025) & (df["month"]==1)]
# combinamos tipos (sum/mean ponderado simple por conteo)
def combine_month_block(block):
    # para métricas de nivel: sum count
    total_count = block["count"].sum()
    # para ratios: promedio simple (o ponderado si quieres)
    avg_dist = block["avg_trip_distance"].mean()
    avg_min  = block["avg_minutes"].mean()
    avg_fpm  = block["avg_fare_per_mile"].mean()
    # para distribución (JS ya viene relativo al ref del pipeline anterior, así que aquí solo guardamos js medios)
    js_h = block["js_hour"].mean()
    js_w = block["js_wday"].mean()
    return pd.Series(dict(count=total_count,
                          avg_trip_distance=avg_dist,
                          avg_minutes=avg_min,
                          avg_fare_per_mile=avg_fpm,
                          js_hour=js_h,
                          js_wday=js_w))

by_ym_alltypes = (df
    .groupby(["year","month"], as_index=False)
    .apply(combine_month_block)
    .reset_index(drop=True)
)

ref_jan25 = by_ym_alltypes[(by_ym_alltypes["year"]==2025) & (by_ym_alltypes["month"]==1)].iloc[0]

def pct_change(a, b):
    if pd.isna(a) or pd.isna(b) or b==0:
        return np.nan
    return (a - b)/b

estacionalidad_vs_jan25 = by_ym_alltypes.copy()
estacionalidad_vs_jan25["count_vs_jan25_pct"]        = estacionalidad_vs_jan25["count"].apply(lambda x: pct_change(x, ref_jan25["count"]))
estacionalidad_vs_jan25["avg_dist_vs_jan25_pct"]     = estacionalidad_vs_jan25["avg_trip_distance"].apply(lambda x: pct_change(x, ref_jan25["avg_trip_distance"]))
estacionalidad_vs_jan25["avg_min_vs_jan25_pct"]      = estacionalidad_vs_jan25["avg_minutes"].apply(lambda x: pct_change(x, ref_jan25["avg_minutes"]))
estacionalidad_vs_jan25["farepm_vs_jan25_pct"]       = estacionalidad_vs_jan25["avg_fare_per_mile"].apply(lambda x: pct_change(x, ref_jan25["avg_fare_per_mile"]))

estacionalidad_vs_jan25.to_csv(OUT_DIR/"seasonality_vs_2025_01_alltypes.csv", index=False)
print("✅ seasonality_vs_2025_01_alltypes.csv guardado")

# =========================
# 2) Estacionalidad mensual
#    VISTA B: cada mes (ene..dic) comparado con el MISMO mes de 2025
#    (útil para estacionalidad pura)
# =========================
ref_2025_by_month = (by_ym_alltypes[by_ym_alltypes["year"]==2025]
                     .set_index("month")[["count","avg_trip_distance","avg_minutes","avg_fare_per_mile"]])

def compare_to_2025_month(row):
    m = row["month"]
    base = ref_2025_by_month.loc[m] if m in ref_2025_by_month.index else None
    out = {}
    for k in ["count","avg_trip_distance","avg_minutes","avg_fare_per_mile"]:
        out[f"{k}_vs_same_month_2025_pct"] = pct_change(row[k], base[k]) if base is not None else np.nan
    return pd.Series(out)

estacionalidad_vs_same_month_2025 = by_ym_alltypes.copy()
estacionalidad_vs_same_month_2025 = pd.concat(
    [estacionalidad_vs_same_month_2025, estacionalidad_vs_same_month_2025.apply(compare_to_2025_month, axis=1)],
    axis=1
)
estacionalidad_vs_same_month_2025.to_csv(OUT_DIR/"seasonality_vs_same_month_2025_alltypes.csv", index=False)
print("✅ seasonality_vs_same_month_2025_alltypes.csv guardado")

# =========================
# 3) Cambios YoY en fare_per_mile y minutes
#    (global y por tipo)
# =========================
# Global (todos los tipos combinados por año)
y_agg = (df
    .groupby(["year"], as_index=False)
    .agg(avg_fare_per_mile=("avg_fare_per_mile","mean"),
         avg_minutes=("avg_minutes","mean"),
         count=("count","mean"))  # media de conteo mensual (proxy)
    .sort_values("year")
)
y_agg["farepm_yoy_pct"] = y_agg["avg_fare_per_mile"].pct_change()
y_agg["minutes_yoy_pct"] = y_agg["avg_minutes"].pct_change()
y_agg.to_csv(OUT_DIR/"yoy_global.csv", index=False)
print("✅ yoy_global.csv guardado")

# Por tipo
y_type = (df
    .groupby(["year","trip_type"], as_index=False)
    .agg(avg_fare_per_mile=("avg_fare_per_mile","mean"),
         avg_minutes=("avg_minutes","mean"),
         count=("count","mean"))
    .sort_values(["trip_type","year"])
)
y_type["farepm_yoy_pct"]  = y_type.groupby("trip_type")["avg_fare_per_mile"].pct_change()
y_type["minutes_yoy_pct"] = y_type.groupby("trip_type")["avg_minutes"].pct_change()
y_type.to_csv(OUT_DIR/"yoy_by_type.csv", index=False)
print("✅ yoy_by_type.csv guardado")

# =========================
# Extras: tablas pivot útiles
# =========================
# JS promedio por año y tipo (matriz)
pivot_js_hour = js_by_type_year.pivot(index="trip_type", columns="year", values="js_hour_mean")
pivot_js_wday = js_by_type_year.pivot(index="trip_type", columns="year", values="js_wday_mean")
pivot_js_hour.to_csv(OUT_DIR/"pivot_js_hour.csv")
pivot_js_wday.to_csv(OUT_DIR/"pivot_js_wday.csv")
print("✅ pivot_js_hour.csv y pivot_js_wday.csv guardados")

print("\nListo. Archivos generados en 'analysis_outputs/'.")
# Out:
# ✅ js_by_type_year.csv guardado
# ✅ js_all_year.csv guardado
# ✅ seasonality_vs_2025_01_alltypes.csv guardado
# ✅ seasonality_vs_same_month_2025_alltypes.csv guardado
# ✅ yoy_global.csv guardado
# ✅ yoy_by_type.csv guardado
# ✅ pivot_js_hour.csv y pivot_js_wday.csv guardados
#
# Listo. Archivos generados en 'analysis_outputs/'.
# C:\Users\User\AppData\Local\Temp\ipykernel_8688\2119401341.py:70: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(combine_month_block)

# %%
import pandas as pd
from pathlib import Path

OUT_DIR = Path("analysis_outputs")

# ======================
# 1) Resumen de JS por tipo y año
# ======================
js_by_type_year = pd.read_csv(OUT_DIR/"js_by_type_year.csv")
print("📊 --- JS promedio por tipo y año ---")
print(js_by_type_year.round(4))

# ======================
# 2) JS global por año
# ======================
js_all_year = pd.read_csv(OUT_DIR/"js_all_year.csv")
print("\n🌍 --- JS global (todos los tipos combinados) ---")
print(js_all_year.round(4))

# ======================
# 3) Cambios anuales en tarifa/milla y minutos (global)
# ======================
yoy_global = pd.read_csv(OUT_DIR/"yoy_global.csv")
print("\n💸 --- Cambios YoY globales ---")
print(yoy_global.round(4))

# ======================
# 4) Cambios anuales en tarifa/milla y minutos (por tipo)
# ======================
yoy_by_type = pd.read_csv(OUT_DIR/"yoy_by_type.csv")
print("\n🚕 --- Cambios YoY por tipo ---")
print(yoy_by_type.round(4))

# ======================
# 5) Estacionalidad (variación mensual respecto a enero 2025)
# ======================
seasonality = pd.read_csv(OUT_DIR/"seasonality_vs_2025_01_alltypes.csv")
print("\n📅 --- Ejemplo de estacionalidad (primeros 12 meses) ---")
print(seasonality.head(12).round(3))

# ======================
# 6) (Opcional) Estacionalidad mes a mes vs mismo mes 2025
# ======================
seasonality_same = pd.read_csv(OUT_DIR/"seasonality_vs_same_month_2025_alltypes.csv")
print("\n📆 --- Estacionalidad comparada con el mismo mes de 2025 (primeros 12 meses) ---")
print(seasonality_same.head(12).round(3))
# Out:
# 📊 --- JS promedio por tipo y año ---
#     year trip_type  js_hour_mean  js_wday_mean    count_mean
# 0   2022     fhvhv        0.0908        0.0878  1.770134e+07
# 1   2022     green        0.0833        0.0618  7.003350e+04
# 2   2022    yellow        0.0536        0.0644  3.304675e+06
# 3   2023     fhvhv        0.0923        0.0865  1.937417e+07
# 4   2023     green        0.0656        0.0585  6.558833e+04
# 5   2023    yellow        0.0598        0.0591  3.192519e+06
# 6   2024     fhvhv        0.0920        0.0859  1.995587e+07
# 7   2024     green        0.0663        0.0644  5.501817e+04
# 8   2024    yellow        0.0602        0.0670  3.430810e+06
# 9   2025     fhvhv        0.0863        0.0778  1.998996e+07
# 10  2025     green        0.0750        0.0642  4.973975e+04
# 11  2025    yellow        0.0628        0.0661  3.944555e+06
#
# 🌍 --- JS global (todos los tipos combinados) ---
#    year  js_hour_mean  js_wday_mean    count_mean
# 0  2022        0.0759        0.0713  7.025350e+06
# 1  2023        0.0726        0.0680  7.544092e+06
# 2  2024        0.0728        0.0725  7.813900e+06
# 3  2025        0.0747        0.0693  7.994751e+06
#
# 💸 --- Cambios YoY globales ---
#    year  avg_fare_per_mile  avg_minutes         count  farepm_yoy_pct  \
# 0  2022             9.3351      31.8078  7.025350e+06             NaN
# 1  2023            10.4969      20.2829  7.544092e+06          0.1245
# 2  2024            11.9296      20.5684  7.813900e+06          0.1365
# 3  2025            13.5196      20.5473  7.994751e+06          0.1333
#
#    minutes_yoy_pct
# 0              NaN
# 1          -0.3623
# 2           0.0141
# 3          -0.0010
#
# 🚕 --- Cambios YoY por tipo ---
#     year trip_type  avg_fare_per_mile  avg_minutes         count  \
# 0   2022     fhvhv             6.7782      24.5015  1.770134e+07
# 1   2023     fhvhv             7.0238      24.4706  1.937417e+07
# 2   2024     fhvhv             7.4815      24.6622  1.995587e+07
# 3   2025     fhvhv             7.6584      24.2127  1.998996e+07
# 4   2022     green            12.1384      20.0905  7.003350e+04
# 5   2023     green            13.1680      19.6182  6.558833e+04
# 6   2024     green            14.7650      19.6372  5.501817e+04
# 7   2025     green            14.7681      20.8363  4.973975e+04
# 8   2022    yellow             9.0887      50.8313  3.304675e+06
# 9   2023    yellow            11.2988      16.7598  3.192519e+06
# 10  2024    yellow            13.5424      17.4057  3.430810e+06
# 11  2025    yellow            18.1325      16.5930  3.944555e+06
#
#     farepm_yoy_pct  minutes_yoy_pct
# 0              NaN              NaN
# 1           0.0362          -0.0013
# 2           0.0652           0.0078
# 3           0.0236          -0.0182
# 4              NaN              NaN
# 5           0.0848          -0.0235
# 6           0.1213           0.0010
# 7           0.0002           0.0611
# 8              NaN              NaN
# 9           0.2432          -0.6703
# 10          0.1986           0.0385
# 11          0.3389          -0.0467
#
# 📅 --- Ejemplo de estacionalidad (primeros 12 meses) ---
#     year  month       count  avg_trip_distance  avg_minutes  \
# 0   2022      1  17278017.0             29.255       18.169
# 1   2022      2  19068113.0             35.581       19.569
# 2   2022      3  22159967.0             25.757       20.051
# 3   2022      4  21428617.0             34.487       20.330
# 4   2022      5  21822521.0             43.547       21.467
# 5   2022      6  21411917.0             38.571      155.914
# 6   2022      7  20703205.0             32.505       20.065
# 7   2022      8  20404293.0             21.626       20.259
# 8   2022      9  21046349.0             36.446       22.189
# 9   2022     10  23050823.0             34.519       21.358
# 10  2022     11  21400926.0             31.561       21.314
# 11  2022     12  23137835.0             16.665       21.007
#
#     avg_fare_per_mile  js_hour  js_wday  count_vs_jan25_pct  \
# 0               7.847    0.080    0.090              -0.278
# 1               8.420    0.074    0.066              -0.203
# 2               8.618    0.072    0.051              -0.074
# 3               8.763    0.083    0.075              -0.104
# 4               8.805    0.075    0.089              -0.088
# 5               9.054    0.076    0.042              -0.105
# 6               9.165    0.075    0.074              -0.135
# 7               9.818    0.073    0.082              -0.147
# 8              10.446    0.072    0.046              -0.120
# 9              10.348    0.079    0.102              -0.037
# 10              9.819    0.075    0.079              -0.106
# 11             10.919    0.078    0.061              -0.033
#
#     avg_dist_vs_jan25_pct  avg_min_vs_jan25_pct  farepm_vs_jan25_pct
# 0                   1.722                -0.055               -0.361
# 1                   2.311                 0.018               -0.315
# 2                   1.397                 0.043               -0.299
# 3                   2.209                 0.058               -0.287
# 4                   3.052                 0.117               -0.284
# 5                   2.589                 7.111               -0.263
# 6                   2.025                 0.044               -0.254
# 7                   1.013                 0.054               -0.201
# 8                   2.392                 0.154               -0.150
# 9                   2.212                 0.111               -0.158
# 10                  1.937                 0.109               -0.201
# 11                  0.551                 0.093               -0.112
#
# 📆 --- Estacionalidad comparada con el mismo mes de 2025 (primeros 12 meses) ---
#     year  month       count  avg_trip_distance  avg_minutes  \
# 0   2022      1  17278017.0             29.255       18.169
# 1   2022      2  19068113.0             35.581       19.569
# 2   2022      3  22159967.0             25.757       20.051
# 3   2022      4  21428617.0             34.487       20.330
# 4   2022      5  21822521.0             43.547       21.467
# 5   2022      6  21411917.0             38.571      155.914
# 6   2022      7  20703205.0             32.505       20.065
# 7   2022      8  20404293.0             21.626       20.259
# 8   2022      9  21046349.0             36.446       22.189
# 9   2022     10  23050823.0             34.519       21.358
# 10  2022     11  21400926.0             31.561       21.314
# 11  2022     12  23137835.0             16.665       21.007
#
#     avg_fare_per_mile  js_hour  js_wday  count_vs_same_month_2025_pct  \
# 0               7.847    0.080    0.090                        -0.278
# 1               8.420    0.074    0.066                        -0.170
# 2               8.618    0.072    0.051                        -0.104
# 3               8.763    0.083    0.075                        -0.099
# 4               8.805    0.075    0.089                        -0.152
# 5               9.054    0.076    0.042                        -0.117
# 6               9.165    0.075    0.074                        -0.123
# 7               9.818    0.073    0.082                        -0.109
# 8              10.446    0.072    0.046                           NaN
# 9              10.348    0.079    0.102                           NaN
# 10              9.819    0.075    0.079                           NaN
# 11             10.919    0.078    0.061                           NaN
#
#     avg_trip_distance_vs_same_month_2025_pct  \
# 0                                      1.722
# 1                                      3.079
# 2                                      1.850
# 3                                      2.450
# 4                                      2.950
# 5                                      4.091
# 6                                      1.902
# 7                                      1.507
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
#
#     avg_minutes_vs_same_month_2025_pct  \
# 0                               -0.055
# 1                               -0.009
# 2                               -0.003
# 3                               -0.023
# 4                               -0.012
# 5                                6.498
# 6                               -0.042
# 7                               -0.036
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
#
#     avg_fare_per_mile_vs_same_month_2025_pct
# 0                                     -0.361
# 1                                     -0.327
# 2                                     -0.347
# 3                                     -0.302
# 4                                     -0.387
# 5                                     -0.402
# 6                                     -0.353
# 7                                     -0.295
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
