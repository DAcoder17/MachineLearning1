# %% [markdown]
# # Simulación de ML Notebooks

# %% [markdown]
# ## 1. Librerias y configuraciones previas

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np


# Preprocesado y modelado
# ==============================================================================
from sklearn.model_selection import train_test_split

#Escalar Variables
from sklearn.preprocessing import MinMaxScaler

#Creacion de los modelos
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix

#EvaluarModelos
import sklearn.metrics as metrics

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns


# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
## Cargar datos con colab
## =============================================================================

from google.colab import drive
import sys

# Path en google
PATH = '/gdrive/MyDrive/01_Academia/02_Cursos/20251001_AprendizajeAutomatico_UdeA/'

UTILS_PATH = PATH + 'utils/'
DATASET_PATH = PATH + 'datasets/'
MODELOS_PATH = PATH + 'modelos/'


# Montar Google Drive
drive.mount('/gdrive')

# Agregar utils al sys.path
sys.path.append(UTILS_PATH)
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Listar archivos del drive de google
##import os

##os.chdir("/gdrive/MyDrive/01_Academia/02_Cursos/20251001_AprendizajeAutomatico_UdeA/")
##!ls

# %% [markdown]
# ## 2. Funciones

# %%
## Aqui se insertan las funciones propias
## =============================================================================

# %% [markdown]
# ## 3. Carga del dataset

# %%
#Se crea un dataframe d con los datos obtenidos de archivo de entrada
d = pd.read_csv(DATASET_PATH + '02_GermanCredit.csv')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               1000 non-null   int64
#  1   checking_account_status   1000 non-null   object
#  2   loan_duration_mo          1000 non-null   int64
#  3   credit_history            1000 non-null   object
#  4   purpose                   1000 non-null   object
#  5   loan_amount               1000 non-null   int64
#  6   savings_account_balance   1000 non-null   object
#  7   time_employed_yrs         1000 non-null   object
#  8   payment_pcnt_income       1000 non-null   int64
#  9   gender_status             1000 non-null   object
#  10  other_signators           1000 non-null   object
#  11  time_in_residence         1000 non-null   int64
#  12  property                  1000 non-null   object
#  13  age_yrs                   1000 non-null   int64
#  14  other_credit_outstanding  1000 non-null   object
#  15  home_ownership            1000 non-null   object
#  16  number_loans              1000 non-null   int64
#  17  job_category              1000 non-null   object
#  18  dependents                1000 non-null   int64
#  19  telephone                 1000 non-null   object
#  20  foreign_worker            1000 non-null   object
#  21  bad_credit                1000 non-null   int64
# dtypes: int64(9), object(13)
# memory usage: 172.0+ KB

# %%
d.head(2)
# Out:
#    Customer ID checking_account_status  loan_duration_mo  \
# 0      1122334                  < 0 DM                 6
# 1      6156361              0 - 200 DM                48
#
#                             credit_history           purpose  loan_amount  \
# 0  critical account - other non-bank loans  radio/television         1169
# 1                       current loans paid  radio/television         5951
#
#   savings_account_balance time_employed_yrs  payment_pcnt_income  \
# 0            unknown/none        >= 7 years                    4
# 1                < 100 DM       1 - 4 years                    2
#
#                        gender_status  ...     property  age_yrs  \
# 0                        male-single  ...  real estate       67
# 1  female-divorced/separated/married  ...  real estate       22
#
#   other_credit_outstanding  home_ownership number_loans job_category  \
# 0                     none             own            2      skilled
# 1                     none             own            1      skilled
#
#    dependents telephone  foreign_worker bad_credit
# 0           1       yes             yes          0
# 1           1      none             yes          1
#
# [2 rows x 22 columns]

# %%
#Borrando columnas innecesarias
d.drop(['Customer ID'], axis='columns', inplace=True)

# %%
# Transformación del tipo de dato de la variable loan_amount
# realmente es un ejemplo dado que no es necesario porque la variable es originalmente numérica

d['loan_amount'] = pd.to_numeric(d['loan_amount'])

# %%
#Verificación y eliminación de registros duplicados

#Verificación de registros duplicados
d.loc[d.duplicated()]
# Out:
# Empty DataFrame
# Columns: [checking_account_status, loan_duration_mo, credit_history, purpose, loan_amount, savings_account_balance, time_employed_yrs, payment_pcnt_income, gender_status, other_signators, time_in_residence, property, age_yrs, other_credit_outstanding, home_ownership, number_loans, job_category, dependents, telephone, foreign_worker, bad_credit]
# Index: []
#
# [0 rows x 21 columns]

# %%
# eliminación de registros duplicados
d = d.drop_duplicates()

#Reiniciar el indice
d.reset_index(drop=True, inplace=True)

# %%
#verificacion de completitud de los datos
for col in d.columns:
    print (col, np.sum(pd.isnull(d[col])))
# Out:
# checking_account_status 0
# loan_duration_mo 0
# credit_history 0
# purpose 0
# loan_amount 0
# savings_account_balance 0
# time_employed_yrs 0
# payment_pcnt_income 0
# gender_status 0
# other_signators 0
# time_in_residence 0
# property 0
# age_yrs 0
# other_credit_outstanding 0
# home_ownership 0
# number_loans 0
# job_category 0
# dependents 0
# telephone 0
# foreign_worker 0
# bad_credit 0

# %% [markdown]
# ## 4. Visualización de datos

# %% [markdown]
# ### Variables de entrada

# %%
#Lista de variables categóricas
catCols = d.select_dtypes(include = ["object", 'category']).columns.tolist()

d[catCols].head()
# Out:
#   checking_account_status                           credit_history  \
# 0                  < 0 DM  critical account - other non-bank loans
# 1              0 - 200 DM                       current loans paid
# 2                    none  critical account - other non-bank loans
# 3                  < 0 DM                       current loans paid
# 4                  < 0 DM                      past payment delays
#
#                purpose savings_account_balance time_employed_yrs  \
# 0     radio/television            unknown/none        >= 7 years
# 1     radio/television                < 100 DM       1 - 4 years
# 2            education                < 100 DM       4 - 7 years
# 3  furniture/equipment                < 100 DM       4 - 7 years
# 4            car (new)                < 100 DM       1 - 4 years
#
#                        gender_status other_signators  \
# 0                        male-single            none
# 1  female-divorced/separated/married            none
# 2                        male-single            none
# 3                        male-single       guarantor
# 4                        male-single            none
#
#                                   property other_credit_outstanding  \
# 0                              real estate                     none
# 1                              real estate                     none
# 2                              real estate                     none
# 3  building society savings/life insurance                     none
# 4                             unknown-none                     none
#
#   home_ownership        job_category telephone foreign_worker
# 0            own             skilled       yes            yes
# 1            own             skilled      none            yes
# 2            own  unskilled-resident      none            yes
# 3       for free             skilled      none            yes
# 4       for free             skilled      none            yes

# %%
#Lista de variables numéricas

numCols=d.select_dtypes(include = ['float64','int32','int64']).columns.tolist()
d[numCols].head()
# Out:
#    loan_duration_mo  loan_amount  payment_pcnt_income  time_in_residence  \
# 0                 6         1169                    4                  4
# 1                48         5951                    2                  2
# 2                12         2096                    2                  3
# 3                42         7882                    2                  4
# 4                24         4870                    3                  4
#
#    age_yrs  number_loans  dependents  bad_credit
# 0       67             2           1           0
# 1       22             1           1           1
# 2       49             1           2           0
# 3       45             1           2           0
# 4       53             2           2           1

# %%
#Se elimina el elemento Price de la lista de variables numéricas

numCols.remove('bad_credit')

# %% [markdown]
# ### Variable de salida

# %%
d.groupby('bad_credit').bad_credit.count().sort_values(ascending=False)
# Out:
# bad_credit
# 0    700
# 1    300
# Name: bad_credit, dtype: int64

# %%
plt.figure(figsize=(6,4))

plt.title('Gráfica de frecuencia de bad Credit')
sns.countplot(x=d['bad_credit'], palette='nipy_spectral')

plt.show()

# %% [markdown]
# ## 5. Preparación de datos

# %% [markdown]
# ### Imputaciones

# %% [markdown]
# ### Valores atípicos para las variables de entrada

# %% [markdown]
# ### Transformaciones

# %% [markdown]
# ### Creación de Variables Dummies

# %%
# Aplicación de la función de usuario Dummies: one-hot encoding

d =pd.get_dummies(d, drop_first=1)

d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 49 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   loan_duration_mo                                        1000 non-null   int64
#  1   loan_amount                                             1000 non-null   int64
#  2   payment_pcnt_income                                     1000 non-null   int64
#  3   time_in_residence                                       1000 non-null   int64
#  4   age_yrs                                                 1000 non-null   int64
#  5   number_loans                                            1000 non-null   int64
#  6   dependents                                              1000 non-null   int64
#  7   bad_credit                                              1000 non-null   int64
#  8   checking_account_status_< 0 DM                          1000 non-null   bool
#  9   checking_account_status_> 200 DM or salary assignment   1000 non-null   bool
#  10  checking_account_status_none                            1000 non-null   bool
#  11  credit_history_critical account - other non-bank loans  1000 non-null   bool
#  12  credit_history_current loans paid                       1000 non-null   bool
#  13  credit_history_no credit - paid                         1000 non-null   bool
#  14  credit_history_past payment delays                      1000 non-null   bool
#  15  purpose_car (new)                                       1000 non-null   bool
#  16  purpose_car (used)                                      1000 non-null   bool
#  17  purpose_domestic appliances                             1000 non-null   bool
#  18  purpose_education                                       1000 non-null   bool
#  19  purpose_furniture/equipment                             1000 non-null   bool
#  20  purpose_other                                           1000 non-null   bool
#  21  purpose_radio/television                                1000 non-null   bool
#  22  purpose_repairs                                         1000 non-null   bool
#  23  purpose_retraining                                      1000 non-null   bool
#  24  savings_account_balance_500 - 1000 DM                   1000 non-null   bool
#  25  savings_account_balance_< 100 DM                        1000 non-null   bool
#  26  savings_account_balance_>= 1000 DM                      1000 non-null   bool
#  27  savings_account_balance_unknown/none                    1000 non-null   bool
#  28  time_employed_yrs_4 - 7 years                           1000 non-null   bool
#  29  time_employed_yrs_< 1 year                              1000 non-null   bool
#  30  time_employed_yrs_>= 7 years                            1000 non-null   bool
#  31  time_employed_yrs_unemployed                            1000 non-null   bool
#  32  gender_status_male-divorced/separated                   1000 non-null   bool
#  33  gender_status_male-married/widowed                      1000 non-null   bool
#  34  gender_status_male-single                               1000 non-null   bool
#  35  other_signators_guarantor                               1000 non-null   bool
#  36  other_signators_none                                    1000 non-null   bool
#  37  property_car or other                                   1000 non-null   bool
#  38  property_real estate                                    1000 non-null   bool
#  39  property_unknown-none                                   1000 non-null   bool
#  40  other_credit_outstanding_none                           1000 non-null   bool
#  41  other_credit_outstanding_stores                         1000 non-null   bool
#  42  home_ownership_own                                      1000 non-null   bool
#  43  home_ownership_rent                                     1000 non-null   bool
#  44  job_category_skilled                                    1000 non-null   bool
#  45  job_category_unemployed-unskilled-non-resident          1000 non-null   bool
#  46  job_category_unskilled-resident                         1000 non-null   bool
#  47  telephone_yes                                           1000 non-null   bool
#  48  foreign_worker_yes                                      1000 non-null   bool
# dtypes: bool(41), int64(8)
# memory usage: 102.7 KB

# %%
d.head(3)
# Out:
#    loan_duration_mo  loan_amount  payment_pcnt_income  time_in_residence  \
# 0                 6         1169                    4                  4
# 1                48         5951                    2                  2
# 2                12         2096                    2                  3
#
#    age_yrs  number_loans  dependents  bad_credit  \
# 0       67             2           1           0
# 1       22             1           1           1
# 2       49             1           2           0
#
#    checking_account_status_< 0 DM  \
# 0                            True
# 1                           False
# 2                           False
#
#    checking_account_status_> 200 DM or salary assignment  ...  \
# 0                                              False      ...
# 1                                              False      ...
# 2                                              False      ...
#
#    property_unknown-none  other_credit_outstanding_none  \
# 0                  False                           True
# 1                  False                           True
# 2                  False                           True
#
#    other_credit_outstanding_stores  home_ownership_own  home_ownership_rent  \
# 0                            False                True                False
# 1                            False                True                False
# 2                            False                True                False
#
#    job_category_skilled  job_category_unemployed-unskilled-non-resident  \
# 0                  True                                           False
# 1                  True                                           False
# 2                 False                                           False
#
#    job_category_unskilled-resident  telephone_yes  foreign_worker_yes
# 0                            False           True                True
# 1                            False          False                True
# 2                             True          False                True
#
# [3 rows x 49 columns]

# %% [markdown]
# ## 6. Creación del modelo

# %% [markdown]
# ### Dividir el conjunto de datos

# %%
#Se establece las variables de entrada 'X' y la variable de salida 'y'
X = d.drop(columns ='bad_credit')
y = d['bad_credit']

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    1
# 999    0
# Name: bad_credit, Length: 1000, dtype: int64

# %%
# Se crean los datasets de entrenamiento y prueba para las variables de entrada y salida

X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y.values.reshape(-1,1),
                                        train_size   = 0.8,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %% [markdown]
# ### Escalar Variables

# %%
#Se establecen las variables numéricas a escalar

#Num_vars se le asigna la lista con las variables numerivas para posteriormente escalarlas
num_vars = numCols

print(num_vars)
# Out:
# ['loan_duration_mo', 'loan_amount', 'payment_pcnt_income', 'time_in_residence', 'age_yrs', 'number_loans', 'dependents']

# %%
#Escalar Variables númericas

pd.set_option('display.float_format', lambda x: '%.4f' % x)

# Se crea un objeto MinMaxScaler
scaler = MinMaxScaler()

# Se escalan los valores del dataset entrenamiento y prueba de las columnas numéricas
X_train[num_vars] = scaler.fit_transform(X_train[num_vars])
X_test[num_vars] = scaler.transform(X_test[num_vars])

X_train[num_vars].head()
# Out:
#      loan_duration_mo  loan_amount  payment_pcnt_income  time_in_residence  \
# 281            0.0357       0.2400               0.0000             1.0000
# 42             0.2500       0.3276               0.3333             1.0000
# 255            0.4643       0.1045               1.0000             0.3333
# 906            0.3036       0.1933               0.3333             0.3333
# 394            0.1429       0.0403               0.0000             1.0000
#
#      age_yrs  number_loans  dependents
# 281   0.2321        0.0000      0.0000
# 42    0.4464        0.0000      1.0000
# 255   0.0893        0.0000      0.0000
# 906   0.0893        0.0000      0.0000
# 394   0.0000        0.0000      0.0000

# %% [markdown]
# ### Creación del modelo

# %%
# Creación del modelo randomForest con con 10 árboles y 5 niveles de profundidad

modelo1 = RandomForestClassifier(
            n_estimators =  10,
            max_features =  'sqrt',
            max_depth    =  5,
            criterion    = 'gini'
         )


# Entrenamiento del modelo

modelo1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=10)

# %% [markdown]
# ### Evaluación del modelo

# %%
# Ejecución del modelo con los datos de test
y_pred = modelo1.predict(X_test)

print("Random Forest:",metrics.accuracy_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# Random Forest: 0.725
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83       138
#            1       0.77      0.16      0.27        62
#
#     accuracy                           0.72       200
#    macro avg       0.75      0.57      0.55       200
# weighted avg       0.74      0.72      0.66       200

# %% [markdown]
# ## 7. Afinando el modelo (tuning)

# %%
# Creación del modelo randomForest con con 10 árboles y 5 niveles de profundidad

modelo2 = RandomForestClassifier(
            n_estimators =  10,
            max_features =  'sqrt',
            class_weight = "balanced",
            max_depth    =  5,
            criterion    = 'gini'
         )


# Entrenamiento del modelo

modelo2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=10)

# %% [markdown]
# ### Evaluación del modelo

# %%
# Ejecución del modelo con los datos de test

y_pred2 = modelo2.predict(X_test)

print("Random Forest:",metrics.accuracy_score(y_test, y_pred2))
print(metrics.classification_report(y_test, y_pred2))
# Out:
# Random Forest: 0.76
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       138
#            1       0.59      0.73      0.65        62
#
#     accuracy                           0.76       200
#    macro avg       0.73      0.75      0.73       200
# weighted avg       0.78      0.76      0.77       200

# %% [markdown]
# ## 8. Prueba

# %% [markdown]
# ### Evaluar algunas instancias (o ejemplos)

# %%
# Concatenar X_test y y_test
df_prep = pd.DataFrame(np.c_[X_test, y_test], columns= X_test.columns.tolist()+['bad_credit_Real'])

# %%
# Generar una muestra de 10 ejemplos de df_prep
x_i = df_prep.sample(n=10, random_state=1234)
x_i
# Out:
#     loan_duration_mo loan_amount payment_pcnt_income time_in_residence  \
# 197           0.3571      0.0944              1.0000            1.0000
# 157           0.5714      0.5945              1.0000            0.3333
# 31            0.5714      0.2501              1.0000            0.0000
# 48            0.1964      0.2792              0.0000            1.0000
# 63            0.3571      0.1564              0.6667            0.3333
# 59            0.0893      0.0628              0.3333            0.0000
# 5             0.2500      0.0544              1.0000            1.0000
# 7             0.7857      0.3714              0.0000            0.0000
# 117           0.3571      0.0617              1.0000            1.0000
# 108           0.5714      0.1557              1.0000            1.0000
#
#     age_yrs number_loans dependents checking_account_status_< 0 DM  \
# 197  0.4107       0.3333     0.0000                          False
# 157  0.1964       0.0000     0.0000                          False
# 31   0.1964       0.0000     0.0000                          False
# 48   0.2857       0.0000     0.0000                          False
# 63   0.0536       0.0000     0.0000                          False
# 59   0.1429       0.0000     0.0000                          False
# 5    0.7500       0.0000     0.0000                          False
# 7    0.2679       0.3333     0.0000                           True
# 117  0.1071       0.0000     0.0000                           True
# 108  0.3036       0.0000     0.0000                          False
#
#     checking_account_status_> 200 DM or salary assignment  \
# 197                                              False
# 157                                              False
# 31                                               False
# 48                                               False
# 63                                               False
# 59                                               False
# 5                                                False
# 7                                                False
# 117                                              False
# 108                                              False
#
#     checking_account_status_none  ... other_credit_outstanding_none  \
# 197                        False  ...                          True
# 157                         True  ...                          True
# 31                         False  ...                          True
# 48                          True  ...                          True
# 63                         False  ...                          True
# 59                         False  ...                         False
# 5                          False  ...                          True
# 7                          False  ...                          True
# 117                        False  ...                          True
# 108                         True  ...                          True
#
#     other_credit_outstanding_stores home_ownership_own home_ownership_rent  \
# 197                           False              False                True
# 157                           False               True               False
# 31                            False               True               False
# 48                            False              False               False
# 63                            False              False                True
# 59                            False               True               False
# 5                             False              False               False
# 7                             False               True               False
# 117                           False              False                True
# 108                           False               True               False
#
#     job_category_skilled job_category_unemployed-unskilled-non-resident  \
# 197                 True                                          False
# 157                False                                          False
# 31                 False                                          False
# 48                  True                                          False
# 63                  True                                          False
# 59                  True                                          False
# 5                   True                                          False
# 7                   True                                          False
# 117                 True                                          False
# 108                 True                                          False
#
#     job_category_unskilled-resident telephone_yes foreign_worker_yes  \
# 197                           False          True               True
# 157                           False          True               True
# 31                            False          True               True
# 48                            False         False               True
# 63                            False          True               True
# 59                            False          True               True
# 5                             False         False               True
# 7                             False          True               True
# 117                           False         False               True
# 108                           False         False               True
#
#     bad_credit_Real
# 197               0
# 157               0
# 31                0
# 48                0
# 63                1
# 59                0
# 5                 0
# 7                 1
# 117               1
# 108               0
#
# [10 rows x 49 columns]

# %%
# Predecir los valores para la muestra x_i utilizando el modelo2
resultadoPredict =modelo2.predict(x_i.drop(columns ='bad_credit_Real'))
resultadoPredict
# Out:
# array([0, 0, 1, 0, 1, 0, 1, 1, 1, 0])

# %%
# Convertir el array numpy resultadoPredic en un DataFrame de pandas
resultadoPredict_df = pd.DataFrame(resultadoPredict, columns=['bad_credit_Predict'])

# %%
# Concatenar x_i con el DataFrame de las predicciones
concatenated_df = pd.concat([x_i.reset_index(drop=True), resultadoPredict_df], axis=1)

concatenated_df[['bad_credit_Real', 'bad_credit_Predict']]
# Out:
#   bad_credit_Real  bad_credit_Predict
# 0               0                   0
# 1               0                   0
# 2               0                   1
# 3               0                   0
# 4               1                   1
# 5               0                   0
# 6               0                   1
# 7               1                   1
# 8               1                   1
# 9               0                   0

# %%
# Crear una nueva columna llamada 'Clasificación' basada en las predicciones y los valores reales
concatenated_df['Clasificación'] = np.where(concatenated_df['bad_credit_Real'] == concatenated_df['bad_credit_Predict'], \
'Correcto', 'Incorrecto')

# Mostrar los resultados de la clasificación
concatenated_df[['bad_credit_Real', 'bad_credit_Predict', 'Clasificación']]
# Out:
#   bad_credit_Real  bad_credit_Predict Clasificación
# 0               0                   0      Correcto
# 1               0                   0      Correcto
# 2               0                   1    Incorrecto
# 3               0                   0      Correcto
# 4               1                   1      Correcto
# 5               0                   0      Correcto
# 6               0                   1    Incorrecto
# 7               1                   1      Correcto
# 8               1                   1      Correcto
# 9               0                   0      Correcto
